# %%
###############   Auto EDA --------------------------------------------------------------






#### Pandas Profiling,...........................

# pip install --upgrade ydata-profiling
import pandas as pd
from ydata_profiling import ProfileReport
import os

profile = ProfileReport(df, title = "City Traffic Accident Risk Analysis", explorative = True)
output_file = "CTARA.html"
profile.to_file(output_file)

print(f"✅ Report saved at: {os.path.abspath(output_file)}")
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# PAIRWISE CALCULATION LENGTH WARNING: There are 222 features in this dataframe and the 'pairwise_analysis' parameter is set to 'auto'.
# Pairwise analysis is exponential in length: 222 features will cause ~49284 pairs to be evaluated, which could take a long time.
#
# You must call the function with the parameter pairwise_analysis='on' or 'off' to explicitly select desired behavior.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 13
#       9 import sweetviz as sv
#      11 s = sv.analyze(df)
# ---> 13 s.show_html()
#      15 ##### D-Tale...............................
#      16
#      17
#      18 # pip install dtale # please install werkzeug appropriate version (pip install werkzeug==2.0.3)
#      19 import dtale
#
# File ~\anaconda3\Lib\site-packages\sweetviz\dataframe_report.py:549, in DataframeReport.show_html(self, filepath, open_browser, layout, scale)
#     547 sv_html.set_summary_positions(self)
#     548 sv_html.generate_html_detail(self)
# --> 549 if self.associations_html_source:
#     550     self.associations_html_source = sv_html.generate_html_associations(self, "source")
#     551 if self.associations_html_compare:
#
# AttributeError: 'DataframeReport' object has no attribute 'associations_html_source'

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\badam\Downloads\cleaned_CTARA_dataset.csv")

# %%
##### Sweetviz............................
###  pip install sweetviz
import sweetviz as sv 

s = sv.analyze(df)

s.show_html()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# PAIRWISE CALCULATION LENGTH WARNING: There are 222 features in this dataframe and the 'pairwise_analysis' parameter is set to 'auto'.
# Pairwise analysis is exponential in length: 222 features will cause ~49284 pairs to be evaluated, which could take a long time.
#
# You must call the function with the parameter pairwise_analysis='on' or 'off' to explicitly select desired behavior.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 7
#       3 import sweetviz as sv
#       5 s = sv.analyze(df)
# ----> 7 s.show_html()
#
# File ~\anaconda3\Lib\site-packages\sweetviz\dataframe_report.py:549, in DataframeReport.show_html(self, filepath, open_browser, layout, scale)
#     547 sv_html.set_summary_positions(self)
#     548 sv_html.generate_html_detail(self)
# --> 549 if self.associations_html_source:
#     550     self.associations_html_source = sv_html.generate_html_associations(self, "source")
#     551 if self.associations_html_compare:
#
# AttributeError: 'DataframeReport' object has no attribute 'associations_html_source'

# %%
##### D-Tale...............................


# pip install dtale # please install werkzeug appropriate version (pip install werkzeug==2.0.3)
import dtale
import pandas as pd

df = pd.read_csv(r"C:\Users\badam\Downloads\cleaned_CTARA_dataset.csv")

d = dtale.show(df, host = 'localhost', port = 8000)

d.open_browser()
# Out:
# C:\Users\badam\anaconda3\Lib\site-packages\kaleido\__init__.py:14: UserWarning:
#
#
#
# Warning: You have Plotly version 5.24.1, which is not compatible with this version of Kaleido (1.0.0).
#
# This means that static image generation (e.g. `fig.write_image()`) will not work.
#
# Please upgrade Plotly to version 6.1.1 or greater, or downgrade Kaleido to version 0.2.1.
